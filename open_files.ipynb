# %%
import pandas as pd
import numpy as np
import os

# %%
big_df=pd.DataFrame()

# %%
for root, dirs, files in os.walk('ao3_datasets/batch_2'):
    for name in sorted(files):
        fname = os.path.join(root, name)
        print(fname)
        df=pd.read_csv(fname)
        big_df = pd.concat([big_df,df])
# Out:
# ao3_datasets/batch_2\ao3_data_06.csv
# ao3_datasets/batch_2\ao3_data_07.csv
# ao3_datasets/batch_2\ao3_data_08.csv
# ao3_datasets/batch_2\ao3_data_09.csv
# ao3_datasets/batch_2\ao3_data_10.csv

# %%
big_df = big_df.drop_duplicates()
big_df = big_df.drop(columns=["Unnamed: 0"])

# %%
big_df
# Out:
#        work_ids                                        work_titles  \
# 0      42991542                                       Those People
# 1      42991494  Nythneidr - or, Hermione Sayre and the Tomb of...
# 2      42991419                                     rises the moon
# 3      42990978  in which Percy beats the Ever Loving Shit out ...
# 4      42991140                                  You Don't Know Me
# ...         ...                                                ...
# 11975  28182996                               The Girl Talk Series
# 11976  28106121                                        Being Human
# 11977  28182213                                  Impostor Syndrome
# 11978  28181535                     D.S.S. Enterprise cont. Part I
# 11979  28181355                                      Bring Me Back
#
#                     authors  \
# 0             AlliCassandra
# 1      thehonorablewangfire
# 2             I_need_my_cat
# 3       thesbian_who_writes
# 4            TheQueerTailor
# ...                     ...
# 11975                adenei
# 11976        orphan_account
# 11977             Guest2357
# 11978          NaomiPhoenix
# 11979        orphan_account
#
#                                                  fandoms  iscrossover  \
# 0       Fantastic Beasts and Where to Find Them (Movies)            0
# 1                           Harry Potter - J. K. Rowling            0
# 2                           Harry Potter - J. K. Rowling            0
# 3                           Harry Potter - J. K. Rowling            0
# 4                           Harry Potter - J. K. Rowling            0
# ...                                                  ...          ...
# 11975                       Harry Potter - J. K. Rowling            0
# 11976                       Harry Potter - J. K. Rowling            0
# 11977                       Harry Potter - J. K. Rowling            0
# 11978  Harry Potter - J. K. Rowling, Stargate - All M...            1
# 11979                       Harry Potter - J. K. Rowling            0
#
#                      ratings                            warnings       genres  \
# 0          General Audiences           No Archive Warnings Apply          F/M
# 1                     Mature  Choose Not To Use Archive Warnings          F/F
# 2                  Not Rated               Major Character Death          Gen
# 3      Teen And Up Audiences      Graphic Depictions Of Violence          M/M
# 4      Teen And Up Audiences  Choose Not To Use Archive Warnings          Gen
# ...                      ...                                 ...          ...
# 11975                 Mature           No Archive Warnings Apply          F/M
# 11976  Teen And Up Audiences  Choose Not To Use Archive Warnings          M/M
# 11977              Not Rated  Choose Not To Use Archive Warnings  No category
# 11978      General Audiences  Choose Not To Use Archive Warnings  No category
# 11979               Explicit  Choose Not To Use Archive Warnings          F/M
#
#             completions       dates  ...  \
# 0         Complete Work  2022/11/10  ...
# 1      Work in Progress  2022/11/10  ...
# 2         Complete Work  2022/11/10  ...
# 3         Complete Work  2022/11/10  ...
# 4      Work in Progress  2022/11/10  ...
# ...                 ...         ...  ...
# 11975     Complete Work  2020/12/20  ...
# 11976  Work in Progress  2020/12/19  ...
# 11977     Complete Work  2020/12/20  ...
# 11978     Complete Work  2020/12/19  ...
# 11979     Complete Work  2020/12/19  ...
#
#                                               characters  \
# 0                      Jacob Kowalski, Queenie Goldstein
# 1      Hermione Granger, Pansy Parkinson, Sirius Blac...
# 2                        Original Characters, Tom Riddle
# 3               Percy Weasley, Oliver Wood, Marcus Flint
# 4      Remus Lupin, Alastor "Mad-Eye" Moody, Sirius B...
# ...                                                  ...
# 11975                                                NaN
# 11976  Sirius Black, Remus Lupin, James Potter, James...
# 11977                     Hermione Granger, Harry Potter
# 11978  Ginny Weasley, Severus Snape, Harry Potter, Pe...
# 11979  Sirius Black, Ginny Weasley, Harry Potter, Ron...
#
#                                                freeforms  \
# 0      Late Night Conversations, Flirting, Romance, F...
# 1      Alternate Universe - Canon Divergence, Post-Wa...
# 2      Angst, Angst and Tragedy, Hurt No Comfort, How...
# 3      Bullying, BAMF Percy Weasley, Protective Percy...
# 4      Disability, Physical Disability, Canon Disable...
# ...                                                  ...
# 11975                                                NaN
# 11976  Marauders Era (Harry Potter), A little bit of ...
# 11977                                                NaN
# 11978                            wizards in space, esama
# 11979                                                NaN
#
#                                                summaries languages wordcounts  \
# 0       When Jacob is woken up by Queenie in the midd...   English      1,071
# 1       Pansy Parkinson, former investigative reporte...   English      5,131
# 2       He feels like he has endured enough and he de...   English      1,265
# 3       This is a messy collage of bits of fics I've ...   English      6,348
# 4       this oneshot which may be more than a one sho...   English      1,872
# ...                                                  ...       ...        ...
# 11975   It all started out with Ginny and Hermione ta...   English      4,219
# 11976   Sirius is a vampire. Remus is a werewolf. Aft...   English     10,180
# 11977   Harry helps Hermione understand just how valu...   English        514
# 11978   A continuation of the Wizards IN SPACE series...   English      8,393
# 11979   After years of being the only one who could h...   English      2,650
#
#       chaptercounts commentcounts kudoscounts bookmarks hitcounts
# 0               1/1             2          18         0       189
# 1               1/?             4          30         8       270
# 2               1/1             0           1         0        13
# 3               5/5            14          75         5     1,526
# 4               1/?             6          64         8     1,121
# ...             ...           ...         ...       ...       ...
# 11975           6/6             5          69        16     1,859
# 11976           6/?             0          21         1       341
# 11977           1/1             1           5         0        39
# 11978           1/1            31         792       105    10,703
# 11979           1/1             1          27         6       671
#
# [91980 rows x 21 columns]

# %%
big_df.to_csv('ao3_FINAL_DATASETS/ao3_datasets_2.csv')
